# %% [markdown]
# <a href="https://colab.research.google.com/github/julien-medina-phd/House/blob/master/Kaggle_House_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **House Prices: Advanced Regression Techniques**

# %% [markdown]
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/overview

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import scale, StandardScaler
from sklearn.svm import LinearSVC, SVC
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
np.random.seed(100)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1d9b6f80-837a-40e7-98c6-e59a936d56fb" name="files[]" multiple disabled />
#      <output id="result-1d9b6f80-837a-40e7-98c6-e59a936d56fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.csv to train (1).csv

# %%
df_given = pd.read_csv("train.csv")
df_compet = pd.read_csv("test.csv")

# %% [markdown]
# # **Data exploration**

# %%
df_given.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df_given.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df_given.shape
# Out:
# (1460, 81)

# %% [markdown]
# **The goal will be to predict the *SalePrice* column from all the other data.**

# %% [markdown]
# There are 1460 houses in the training set.
# Let us see the distribution of the SalePrice.

# %%
df_given.SalePrice
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
df_given.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(20,10))
plt.hist(df_given.SalePrice,50)
plt.xlabel('SalePrice (House price)')
plt.ylabel('Number of houses')
plt.title("Fare distribution of all the passengers")
plt.grid()

# %% [markdown]
# # **Data preprocessing**

# %% [markdown]
# Let us see if there are any nan values.

# %%
df_given.isna().sum()[df_given.isna().sum()!=0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType         8
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# We see that some columns present a lot of missing values. For the moment we decide to drop the columns with more than 680 missing values (over a total of 1460 houses) which are the columns Alley, FireplaceQu, PoolQC, Fence and MiscFeature.

# %%
df_given2 = df_given

# %%
df_given2 = df_given2.drop(['Alley', 'FireplaceQu','PoolQC','Fence','MiscFeature'], axis=1)

# %%
df_given2.isna().sum()[df_given2.isna().sum()!=0]
# Out:
# LotFrontage     259
# MasVnrType        8
# MasVnrArea        8
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinType2     38
# Electrical        1
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageQual       81
# GarageCond       81
# dtype: int64
